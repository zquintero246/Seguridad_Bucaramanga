# %%
# Pandas para manejo de datos
import pandas as pd

# Request para hacer peticiones HTTP
import requests

# MatplotLib para grafos
import matplotlib.pyplot as plt

# %%
#API de datos abiertos de Colombia
url = "https://www.datos.gov.co/resource/x46e-abhz.json"

# Realizar la petición HTTP
response = requests.get(url)

# Verificar si la petición fue exitosa
if response.status_code == 200:

    # Convertir la respuesta en un DataFrame de Pandas
    data = response.json()
    df = pd.DataFrame(data)

else:
    print("Error al obtener los datos: ", response.status_code)

# %%
# Mostra el tipo de dato de cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   descripcion_conducta  1000 non-null   object
#  1   armas_medios          1000 non-null   object
#  2   barrios_hecho         1000 non-null   object
#  3   fecha_hecho           1000 non-null   object
#  4   hora_hecho            1000 non-null   object
#  5   edad                  1000 non-null   object
#  6   sexo                  1000 non-null   object
#  7   movil_victima         1000 non-null   object
#  8   movil_agresor         1000 non-null   object
#  9   clase_sitio           1000 non-null   object
#  10  articulo              1000 non-null   object
#  11  delito_solo           1000 non-null   object
#  12  curso_vida            1000 non-null   object
#  13  curso_vida_orden      1000 non-null   object
#  14  a_o_num               1000 non-null   object
#  15  mes_num               1000 non-null   object
#  16  dia_num               1000 non-null   object
#  17  rango_horario         1000 non-null   object
#  18  tipolog_a             1000 non-null   object
#  19  rango_horario_orden   1000 non-null   object
#  20  dia_nombre            1000 non-null   object
#  21  dia_nombre_orden      1000 non-null   object
#  22  localidad             1000 non-null   object
#  23  num_com               1000 non-null   object
#  24  nom_com               1000 non-null   object
#  25  cantidad_unica        1000 non-null   object
# dtypes: object(26)
# memory usage: 203.3+ KB

# %%
# Mostrar las primeras filas del DataFrame
df.head(100)
# Out:
#             descripcion_conducta                 armas_medios  \
# 0   ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1   ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 2   ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 3   ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 4   ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# ..                           ...                          ...
# 95  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 96  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 97  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 98  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 99  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
#
#           barrios_hecho fecha_hecho hora_hecho edad       sexo movil_victima  \
# 0               MALPASO  2019-06-17   20:30:00   21  MASCULINO         A PIE
# 1   GRANJAS DE PROVENZA  2019-09-12   01:30:00   21  MASCULINO         A PIE
# 2              PROVENZA  2019-04-07   05:10:00   21  MASCULINO         A PIE
# 3        CIUDAD VENECIA  2019-01-30   23:15:00   21  MASCULINO         A PIE
# 4              PROVENZA  2019-06-12   14:30:00   21  MASCULINO         A PIE
# ..                  ...         ...        ...  ...        ...           ...
# 95          LA FLORESTA  2019-05-18   04:30:00   22  MASCULINO         A PIE
# 96         LA CONCORDIA  2019-01-26   21:30:00   22  MASCULINO         A PIE
# 97              LA JOYA  2019-03-08   07:00:00   22  MASCULINO         A PIE
# 98   CABECERA DEL LLANO  2019-07-12   02:00:00   22  MASCULINO         A PIE
# 99   CABECERA DEL LLANO  2019-12-20   23:30:00   22  MASCULINO         A PIE
#
#    movil_agresor    clase_sitio  ... dia_num rango_horario  \
# 0          A PIE  VIAS PUBLICAS  ...      17   20:00-20:59
# 1          A PIE  VIAS PUBLICAS  ...      12     1:00-1:59
# 2          A PIE  VIAS PUBLICAS  ...       7     5:00-5:59
# 3          A PIE  VIAS PUBLICAS  ...      30   23:00-23:59
# 4          A PIE  VIAS PUBLICAS  ...      12   14:00-14:59
# ..           ...            ...  ...     ...           ...
# 95         A PIE  VIAS PUBLICAS  ...      18     4:00-4:59
# 96         A PIE  VIAS PUBLICAS  ...      26   21:00-21:59
# 97         A PIE  VIAS PUBLICAS  ...       8     7:00-7:59
# 98         A PIE  VIAS PUBLICAS  ...      12     2:00-2:59
# 99         A PIE  VIAS PUBLICAS  ...      20   23:00-23:59
#
#                                  tipolog_a rango_horario_orden dia_nombre  \
# 0   DELITOS CONTRA EL PATRIMONIO ECONOMICO                  20      lunes
# 1   DELITOS CONTRA EL PATRIMONIO ECONOMICO                   1     jueves
# 2   DELITOS CONTRA EL PATRIMONIO ECONOMICO                   5    domingo
# 3   DELITOS CONTRA EL PATRIMONIO ECONOMICO                  23  miércoles
# 4   DELITOS CONTRA EL PATRIMONIO ECONOMICO                  14  miércoles
# ..                                     ...                 ...        ...
# 95  DELITOS CONTRA EL PATRIMONIO ECONOMICO                   4     sábado
# 96  DELITOS CONTRA EL PATRIMONIO ECONOMICO                  21     sábado
# 97  DELITOS CONTRA EL PATRIMONIO ECONOMICO                   7    viernes
# 98  DELITOS CONTRA EL PATRIMONIO ECONOMICO                   2    viernes
# 99  DELITOS CONTRA EL PATRIMONIO ECONOMICO                  23    viernes
#
#    dia_nombre_orden               localidad num_com             nom_com  \
# 0                 1                 11. SUR      11                 SUR
# 1                 4            10. PROVENZA      10            PROVENZA
# 2                 7            10. PROVENZA      10            PROVENZA
# 3                 3                 11. SUR      11                 SUR
# 4                 3            10. PROVENZA      10            PROVENZA
# ..              ...                     ...     ...                 ...
# 95                6  12. CABECERA DEL LLANO      12  CABECERA DEL LLANO
# 96                6        06. LA CONCORDIA       6        LA CONCORDIA
# 97                5       05. GARCIA ROVIRA       5       GARCIA ROVIRA
# 98                5  12. CABECERA DEL LLANO      12  CABECERA DEL LLANO
# 99                5  12. CABECERA DEL LLANO      12  CABECERA DEL LLANO
#
#    cantidad_unica
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ..            ...
# 95              1
# 96              1
# 97              1
# 98              1
# 99              1
#
# [100 rows x 26 columns]
